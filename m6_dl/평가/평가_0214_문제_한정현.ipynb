# %% [markdown]
# ## AI기반 챗봇 및 OCR 개발 전문가 과정
#
# ### 교과목명 : 딥러닝
# - 평가일 : 24. 2. 14
# - 성명 : 한정현
# - 점수 :

# %% [markdown]
# Q1. MNIST 데이터셋에 대하여 tensorflow/keras Sequential 모델을 사용하여 아래와 같이 완전 연결 신경망(Feedforward Neural Network)을 구성한 후 모델링 및 평가를 수행하세요.
# - 입력 형태(input_shape): input_shape=(28, 28)로 설정. 이는 모델이 28x28 픽셀 크기의 이미지를 입력으로 받는다는 것을 의미이며 첫 번째 레이어인 Flatten은 이 2D 이미지를 784(28x28) 요소의 1D 배열로 평탄화.Flatten(input_shape=(28, 28))
#
# - 레이어 구성: 모델은 평탄화 레이어(Flatten) 다음에 128개의 뉴런을 가진 완전 연결 레이어(Dense)를 가지고 있으며, 그 다음에는 10개의 출력 뉴런을 가진 또 다른 Dense 레이어가 있다. 출력 레이어는 소프트맥스 활성화 함수를 사용하여 다중 클래스 분류를 수행.
#
# - 컴파일:
#   - optimizer='adam',
#   - loss='sparse_categorical_crossentropy',
#   - metrics=['accuracy']
#
# - epochs=5

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense

# MNIST 데이터셋 로드
mnist = tf.keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
model = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 7s 3ms/step - loss: 2.4171 - accuracy: 0.8406
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3824 - accuracy: 0.9081
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2848 - accuracy: 0.9293
# Epoch 4/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2458 - accuracy: 0.9378
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2203 - accuracy: 0.9444

# %% [markdown]
# Q2. MNIST 데이터셋에 대하여 함수형 API를 사용하여 같은 아래사항을 준수하여  모델 학습 및 평가를 수행하세요.
# - 데이터 정규화 (0과 1 사이의 값으로 스케일링)
# - 입력 데이터의 차원을 (28, 28)에서 모델에 적합한 형태로 조정
# - 레이어 연결(hidden 2개, 출력 1개)
# - 모델 생성
# - 모델 컴파일 : optimizer='adam',loss='sparse_categorical_crossentropy', metrics=['accuracy']
# - 모델 학습 : epochs=5, batch_size=32, validation_split=0.2
# - 모델 평가

# %%
from tensorflow.keras.layers import Input, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist

# MNIST 데이터셋 로드
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
model = Sequential([
    Flatten(input_shape=(28,28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.fit(
    train_images,
    train_labels,
    epochs=5,
    batch_size=32,
    validation_split=0.2
)
# Out:
# Epoch 1/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 3.3298 - accuracy: 0.8531 - val_loss: 0.5877 - val_accuracy: 0.8812
# Epoch 2/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.4588 - accuracy: 0.8946 - val_loss: 0.4390 - val_accuracy: 0.9072
# Epoch 3/5
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.3384 - accuracy: 0.9158 - val_loss: 0.3410 - val_accuracy: 0.9160
# Epoch 4/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2930 - accuracy: 0.9273 - val_loss: 0.3392 - val_accuracy: 0.9253
# Epoch 5/5
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2605 - accuracy: 0.9340 - val_loss: 0.3028 - val_accuracy: 0.9296

# %% [markdown]
# Q3. 주어진 텍스트 데이터셋을 토큰화하고, 다음 사항을 수행하세요.
#
# 데이터셋:
#
# "I love machine learning."<br>
# "I love coding in Python."<br>
# "Machine learning can be fun."
#
# - 각 단어에 고유한 정수 인덱스를 할당하고 각 문장을 정수 시퀀스로 변환하세요.

# %%
from keras.preprocessing.text import Tokenizer

texts = ['I love machine learning', 'I love coding in Python', 'Machine learning can be fun']

# %%
token = Tokenizer(texts)
Tokenizer.fit_on_sequences(sequences=token, self=token)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-5ce547ddcf2e> in <cell line: 2>()
#       1 token = Tokenizer(texts)
# ----> 2 Tokenizer.fit_on_sequences(sequences=token, self=texts)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/text.py in fit_on_sequences(self, sequences)
#     337                 A "sequence" is a list of integer word indices.
#     338         """
# --> 339         self.document_count += len(sequences)
#     340         for seq in sequences:
#     341             seq = set(seq)
#
# AttributeError: 'list' object has no attribute 'document_count'

# %% [markdown]
# Q4. Q3에서 생성한 정수 시퀀스에 패딩을 추가하여 모든 시퀀스의 길이를 동일하게 만드세요.

# %%
from keras.preprocessing.sequence import pad_sequences

# %%
pad_sequences(sequences=token)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-cbec33a92c20> in <cell line: 1>()
# ----> 1 pad_sequences(sequences=token)
#
# NameError: name 'pad_sequences' is not defined

# %% [markdown]
# Q5. 주어진 텍스트 데이터셋에 대해 원-핫 인코딩을 수행하세요. (사용할 최대 단어 수 설정 : num_words=1000)

# %%
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical

# 데이터셋 정의
texts = [ "I love coding in Python.","I love machine learning.", "Machine learning can be fun."]

# %%
token = Tokenizer(num_words=1000)
to_categorical(texts)
